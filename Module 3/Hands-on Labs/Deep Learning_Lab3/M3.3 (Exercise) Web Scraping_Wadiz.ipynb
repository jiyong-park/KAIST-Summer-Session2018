# %% [markdown]
# # KAIST Summer Session 2018
#
# ## Wadiz Scraper (08.13.2018)
#
# --------------------- by Web Scraper ----------------------
# 1. Generating the list of URLs to download
# 2. Downloading the webpage HTML from the URLs
#
# --------------------- by Python -------------------------------
# 3. Parsing the relevant information from the downloaded HTML

# %% [markdown]
# ### 1. Importing the csv file including URL and HTML

# %%
import pandas as pd

df = pd.read_excel('wadiz_scraper.xlsx')
a= df.as_matrix()
print(a[0,0])
print(a[0,1])
# Out:
# [추석 기획전] 설거지가 편해지는 ' 폴더수세미 ' 마지막 앵콜!
# https://www.wadiz.kr/web/campaign/detail/21857
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %% [markdown]
# - Structure of performance_html

# %%
print(a[0,2])
# Out:
# <p class="remaining-day">12일 남음</p>
#
#
#                     <p class="rate-bar"><em style="width:433%"></em></p>
#
#
#                   <p class="achievement-rate"><strong>433</strong>% 달성</p>
#                   <p class="total-amount"><strong>4,338,500</strong>원  펀딩</p>
#                   <p class="total-supporter"><strong>260</strong>명의 서포터</p>

# %% [markdown]
# - Structure of profile_html

# %%
print(a[0,3])
# Out:
# <dl>
#                       <dt><button onclick="goMakerProfile('1231098023');" style="background-image:url(https://cdn.wadiz.kr/wwwwadiz/green002/2018/0708/20180708143244287_21857.jpg/wadiz/resize/92x92/format/jpg/quality/95/optimize);"></button></dt>
#                       <dd>
#                         <p class="name"><a href="#" onclick="goMakerProfile('1231098023');">라미스천연비누</a></p>
#                         <ul class="website">
#
#                           <li><a href="https://smartstore.naver.com/lamissoap" target="_blank" data-external-link="" rel="noopener noreferrer">https://smartstore.naver.com/lamissoap</a></li>
#
#
#                           <li><a href="https://blog.naver.com/lamissoap" target="_blank" data-external-link="" rel="noopener noreferrer">https://blog.naver.com/lamissoap</a></li>
#
#                         </ul>
#                         <ul class="social">
#
#
#
# ...

# %% [markdown]
# ### 2. Parsing the relevant information from the HTML

# %% [markdown]
# ## (Exercise)
# - Scraping the information about crowdfunding performance and creator's profile image.
#
# ![image.png](attachment:image.png)
